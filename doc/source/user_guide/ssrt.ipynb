# %% [markdown]
# # Predict Stop Signal Response Time  (SSRT)
#
# This notebook uses stop signal task fMRI data derrived contrasts from the ABCD study to predict stop signal response time (SSRT). This is an example of a regression type machine learning, and additionally includes an extra example of how to plot ROIs feature importance on brain surfaces from nilearn.
#
# ## Loading Data
#
# We will be loading data from is essentially a big csv file with all the different columns, some slightly processed, from the ABCD DEAP rds (saved r dataframe). The benefit of this approach is that while a little slow, we can just load any column of interest easily as a dataframe.

# %%
import BPt as bp
import pandas as pd

# %%
def load_from_rds(names, eventname='baseline_year_1_arm_1'):
    
    data = pd.read_csv('data/nda_rds_201.csv',
                       usecols=['src_subject_id', 'eventname'] + names,
                       na_values=['777', 999, '999', 777])
    
    data = data.loc[data[data['eventname'] == eventname].index]
    data = data.set_index('src_subject_id')
    data = data.drop('eventname', axis=1)
    
    return data

# %%
# This way we can look at all column avaliable
all_cols = list(pd.read_csv('data/nda_rds_201.csv', nrows=0))
all_cols[:10]
# Out:
# ['subjectid',
#  'src_subject_id',
#  'eventname',
#  'anthro_1_height_in',
#  'anthro_2_height_in',
#  'anthro_3_height_in',
#  'anthro_height_calc',
#  'anthro_weight_cast',
#  'anthro_weight_a_location',
#  'anthro_weight1_lb']

# %%
# Use python list comprehensions to get lists of the column names of interest
contrasts = ['tfmri_sst_all_correct.go.vs.fixation_beta_',
             'tfmri_sst_all_correct.stop.vs.correct.go_beta_',
             'tfmri_sst_all_incorrect.stop.vs.correct.go_beta_']

                 
parcs = ['.destrieux', '_subcort.aseg']

data_cols = [col for col in all_cols
             if any([ct for ct in contrasts if ct in col])
             and any([p for p in parcs if p in col])] + ['sex']
target_col = ['tfmri_sst_all_beh_total_mean.rt']

# %%
# Load the actual data from the saved csv
df = load_from_rds(data_cols + target_col)

# %%
# Cast from a dataframe to BPt Dataset class
data = bp.Dataset(df)
    
# Obsificate subject ID for public example
data.index = list(range(len(data)))

# Set optional verbosity of
data.verbose = 1

# %%
data = data.drop_cols(exclusions=['.ventricle', '_csf', '.white.matter'], scope='_subcort.aseg')
# Out:
# Dropped 27 Columns

# %% [markdown]
# Data in BPt can have one of three roles, these are 'data' by default, 'target' for variable to predict, and 'non input' for variables which we don't use directly as input features. We set 'sex' as non input in this example.

# %%
data = data.set_role('sex', 'non input')
data = data.set_role(target_col, 'target')
data
# Out:
# Dropped 6 Rows
#        tfmri_sst_all_beh_total_mean.rt  \
# 0                           303.070588
# 1                                  NaN
# 2                           207.210728
# 3                           241.179775
# 4                           391.927948
# ...                                ...
# 11870                       169.889647
# 11871                       335.764988
# 11872                       332.246959
# 11873                       358.591304
# 11874                       210.954955
#
#        tfmri_sst_all_correct.go.vs.fixation_beta_cort.destrieux_g.and.s.frontomargin.lh  \
# 0                                               0.142664
# 1                                                    NaN
# 2                                               0.579317
# 3                                               0.289666
# 4                                              -0.141231
# ...                                                  ...
# 11870                                           0.130752
# 11871                                           0.327409
# 11872                                          -0.203417
# 11873                                           0.507308
# 11874                                           0.914101
#
#        tfmri_sst_all_correct.go.vs.fixation_beta_cort.destrieux_g.and.s.occipital.inf.lh  \
# 0                                              -0.169860
# 1                                                    NaN
# 2                                               0.224255
# 3                                               0.188761
# 4                                               0.573906
# ...                                                  ...
# 11870                                           0.100078
# 11871                                          -0.203490
# 11872                                          -0.270940
# 11873                                           0.260868
# 11874                                           0.295187
#
#        tfmri_sst_all_correct.go.vs.fixation_beta_cort.destrieux_g.and.s.paracentral.lh  \
# 0                                              -0.032468
# 1                                                    NaN
# 2                                               0.014918
# 3                                               0.065598
# 4                                               0.398038
# ...                                                  ...
# 11870                                          -0.046066
# 11871                                          -0.112453
# 11872                                          -0.155822
# 11873                                           0.366341
# 11874                                          -0.180328
#
#        tfmri_sst_all_correct.go.vs.fixation_beta_cort.destrieux_g.and.s.subcentral.lh  \
# 0                                               0.265397
# 1                                                    NaN
# 2                                               0.093613
# 3                                               0.152845
# 4                                              -0.054308
# ...                                                  ...
# 11870                                          -0.141273
# 11871                                          -0.042516
# 11872                                          -0.156469
# 11873                                           0.342751
# 11874                                           0.032638
#
#        tfmri_sst_all_correct.go.vs.fixation_beta_cort.destrieux_g.and.s.transv.frontopol.lh  \
# 0                                               0.190945
# 1                                                    NaN
# 2                                              -0.092851
# 3                                               0.151112
# 4                                              -0.319325
# ...                                                  ...
# 11870                                           0.049721
# 11871                                           0.058666
# 11872                                          -0.320934
# 11873                                           0.083437
# 11874                                          -0.208153
#
#        tfmri_sst_all_correct.go.vs.fixation_beta_cort.destrieux_g.and.s.cingul.ant.lh  \
# 0                                               0.168032
# 1                                                    NaN
# 2                                               0.052402
# 3                                              -0.092771
# 4                                              -0.144128
# ...                                                  ...
# 11870                                          -0.103273
# 11871                                          -0.060443
# 11872                                           0.012809
# 11873                                           0.164396
# 11874                                           0.116179
#
#        tfmri_sst_all_correct.go.vs.fixation_beta_cort.destrieux_g.and.s.cingul.mid.ant.lh  \
# 0                                               0.045860
# 1                                                    NaN
# 2                                               0.111399
# 3                                               0.182024
# 4                                              -0.001618
# ...                                                  ...
# 11870                                           0.008791
# 11871                                          -0.024308
# 11872                                           0.012343
# 11873                                           0.376726
# 11874                                          -0.045182
#
#        tfmri_sst_all_correct.go.vs.fixation_beta_cort.destrieux_g.and.s.cingul.mid.post.lh  \
# 0                                               0.081824
# 1                                                    NaN
# 2                                               0.113433
# 3                                               0.096595
# 4                                               0.241128
# ...                                                  ...
# 11870                                           0.059300
# 11871                                          -0.143336
# 11872                                          -0.072679
# 11873                                           0.371823
# 11874                                           0.341190
#
#        tfmri_sst_all_correct.go.vs.fixation_beta_cort.destrieux_g.cingul.post.dorsal.lh  \
# 0                                               0.135374
# 1                                                    NaN
# 2                                               0.006913
# 3                                              -0.051182
# 4                                               0.566345
# ...                                                  ...
# 11870                                          -0.020510
# 11871                                           0.045055
# 11872                                           0.013745
# 11873                                           0.118068
# 11874                                          -0.108107
#
#        ...  \
# 0      ...
# 1      ...
# 2      ...
# 3      ...
# 4      ...
# ...    ...
# 11870  ...
# 11871  ...
# 11872  ...
# 11873  ...
# 11874  ...
#
#        tfmri_sst_all_incorrect.stop.vs.correct.go_beta_subcort.aseg_cerebellum.cortex.rh  \
# 0                                               0.271985
# 1                                                    NaN
# 2                                               0.170224
# 3                                              -0.192650
# 4                                              -0.125728
# ...                                                  ...
# 11870                                           0.080321
# 11871                                           0.018032
# 11872                                           0.115288
# 11873                                          -0.508338
# 11874                                           0.465149
#
#        tfmri_sst_all_incorrect.stop.vs.correct.go_beta_subcort.aseg_thalamus.proper.rh  \
# 0                                               0.158497
# 1                                                    NaN
# 2                                               0.044027
# 3                                              -0.113892
# 4                                               0.060963
# ...                                                  ...
# 11870                                           0.055350
# 11871                                           0.034421
# 11872                                           0.388157
# 11873                                          -0.251212
# 11874                                          -0.110444
#
#        tfmri_sst_all_incorrect.stop.vs.correct.go_beta_subcort.aseg_caudate.rh  \
# 0                                               0.140130
# 1                                                    NaN
# 2                                               0.080984
# 3                                              -0.261145
# 4                                               0.037491
# ...                                                  ...
# 11870                                           0.073250
# 11871                                           0.070082
# 11872                                           0.267505
# 11873                                          -0.517297
# 11874                                          -0.029437
#
#        tfmri_sst_all_incorrect.stop.vs.correct.go_beta_subcort.aseg_putamen.rh  \
# 0                                              -0.022286
# 1                                                    NaN
# 2                                               0.036808
# 3                                              -0.187083
# 4                                               0.092319
# ...                                                  ...
# 11870                                          -0.090321
# 11871                                          -0.069077
# 11872                                           0.366650
# 11873                                          -0.380956
# 11874                                          -0.142340
#
#        tfmri_sst_all_incorrect.stop.vs.correct.go_beta_subcort.aseg_pallidum.rh  \
# 0                                              -0.025535
# 1                                                    NaN
# 2                                               0.191424
# 3                                              -0.082544
# 4                                               0.046954
# ...                                                  ...
# 11870                                           0.016314
# 11871                                           0.080907
# 11872                                           0.134182
# 11873                                          -0.347940
# 11874                                          -0.217486
#
#        tfmri_sst_all_incorrect.stop.vs.correct.go_beta_subcort.aseg_hippocampus.rh  \
# 0                                               0.029847
# 1                                                    NaN
# 2                                              -0.070316
# 3                                              -0.126344
# 4                                              -0.340383
# ...                                                  ...
# 11870                                           0.016634
# 11871                                          -0.041997
# 11872                                           0.338388
# 11873                                          -0.660557
# 11874                                          -0.046869
#
#        tfmri_sst_all_incorrect.stop.vs.correct.go_beta_subcort.aseg_amygdala.rh  \
# 0                                               0.033911
# 1                                                    NaN
# 2                                              -0.047834
# 3                                              -0.103980
# 4                                              -0.349582
# ...                                                  ...
# 11870                                          -0.017871
# 11871                                          -0.229670
# 11872                                           0.167300
# 11873                                          -0.482309
# 11874                                          -0.091805
#
#        tfmri_sst_all_incorrect.stop.vs.correct.go_beta_subcort.aseg_accumbens.area.rh  \
# 0                                              -0.006584
# 1                                                    NaN
# 2                                              -0.071073
# 3                                              -0.127491
# 4                                              -0.177044
# ...                                                  ...
# 11870                                           0.028356
# 11871                                           0.042529
# 11872                                           0.243295
# 11873                                          -0.478043
# 11874                                          -0.121216
#
#        tfmri_sst_all_incorrect.stop.vs.correct.go_beta_subcort.aseg_ventraldc.rh  \
# 0                                               0.234851
# 1                                                    NaN
# 2                                               0.042021
# 3                                              -0.175904
# 4                                              -0.102220
# ...                                                  ...
# 11870                                           0.095318
# 11871                                          -0.075879
# 11872                                           0.312342
# 11873                                          -0.336481
# 11874                                           0.036157
#
#        sex
# 0        F
# 1        F
# 2        M
# 3        M
# 4        M
# ...    ...
# 11870    M
# 11871    F
# 11872    F
# 11873    F
# 11874    F
#
# [11869 rows x 509 columns]

# %%
# Cast sex as a binary variable
data.to_binary('sex', inplace=True)
data['sex']
# Out:
# 0        0
# 1        0
# 2        1
# 3        1
# 4        1
#         ..
# 11870    1
# 11871    0
# 11872    0
# 11873    0
# 11874    0
# Name: sex, Length: 11869, dtype: category
# Categories (2, int64): [0 < 1]

# %%
# Let's drop all missing data
data.dropna(inplace=True)
data.shape
# Out:
# (8847, 509)

# %% [markdown]
# We can filter outliers from the data columns but also the target columns, essentially every 'float' type column.

# %%
data = data.filter_outliers_by_std(n_std=10, scope='float')
# Out:
# Dropped 327 Rows

# %% [markdown]
# We can also plot individual variables

# %%
data.plot(scope='sex', subjects='all', decode_values=True, count=True)
# Out:
# sex: 8520 rows

# %% [markdown]
# ## Define a train-test split

# %% [markdown]
# What if we wanted to define a train-test split? But also do it according to some criteria, say stratifying by sex?

# %%
# First define a CVStrategy that says stratify by sex
sex_strat = bp.CVStrategy(stratify='sex')
sex_strat
# Out:
# CVStrategy(stratify='sex')

# %%
# Apply the test_split
data = data.set_test_split(size=.2, cv_strategy=sex_strat, random_state=2)
data
# Out:
# Performing test split on: 8520 subjects.
# random_state: 2
# Test split size: 0.2
#
# Performed train/test split
# Train size: 6816
# Test size:  1704
#        tfmri_sst_all_beh_total_mean.rt  \
# 0                           303.070588
# 2                           207.210728
# 3                           241.179775
# 4                           391.927948
# 5                           287.037037
# ...                                ...
# 11870                       169.889647
# 11871                       335.764988
# 11872                       332.246959
# 11873                       358.591304
# 11874                       210.954955
#
#        tfmri_sst_all_correct.go.vs.fixation_beta_cort.destrieux_g.and.s.frontomargin.lh  \
# 0                                               0.142664
# 2                                               0.579317
# 3                                               0.289666
# 4                                              -0.141231
# 5                                               0.298622
# ...                                                  ...
# 11870                                           0.130752
# 11871                                           0.327409
# 11872                                          -0.203417
# 11873                                           0.507308
# 11874                                           0.914101
#
#        tfmri_sst_all_correct.go.vs.fixation_beta_cort.destrieux_g.and.s.occipital.inf.lh  \
# 0                                              -0.169860
# 2                                               0.224255
# 3                                               0.188761
# 4                                               0.573906
# 5                                              -0.082675
# ...                                                  ...
# 11870                                           0.100078
# 11871                                          -0.203490
# 11872                                          -0.270940
# 11873                                           0.260868
# 11874                                           0.295187
#
#        tfmri_sst_all_correct.go.vs.fixation_beta_cort.destrieux_g.and.s.paracentral.lh  \
# 0                                              -0.032468
# 2                                               0.014918
# 3                                               0.065598
# 4                                               0.398038
# 5                                              -0.222860
# ...                                                  ...
# 11870                                          -0.046066
# 11871                                          -0.112453
# 11872                                          -0.155822
# 11873                                           0.366341
# 11874                                          -0.180328
#
#        tfmri_sst_all_correct.go.vs.fixation_beta_cort.destrieux_g.and.s.subcentral.lh  \
# 0                                               0.265397
# 2                                               0.093613
# 3                                               0.152845
# 4                                              -0.054308
# 5                                              -0.089213
# ...                                                  ...
# 11870                                          -0.141273
# 11871                                          -0.042516
# 11872                                          -0.156469
# 11873                                           0.342751
# 11874                                           0.032638
#
#        tfmri_sst_all_correct.go.vs.fixation_beta_cort.destrieux_g.and.s.transv.frontopol.lh  \
# 0                                               0.190945
# 2                                              -0.092851
# 3                                               0.151112
# 4                                              -0.319325
# 5                                              -0.224157
# ...                                                  ...
# 11870                                           0.049721
# 11871                                           0.058666
# 11872                                          -0.320934
# 11873                                           0.083437
# 11874                                          -0.208153
#
#        tfmri_sst_all_correct.go.vs.fixation_beta_cort.destrieux_g.and.s.cingul.ant.lh  \
# 0                                               0.168032
# 2                                               0.052402
# 3                                              -0.092771
# 4                                              -0.144128
# 5                                              -0.243239
# ...                                                  ...
# 11870                                          -0.103273
# 11871                                          -0.060443
# 11872                                           0.012809
# 11873                                           0.164396
# 11874                                           0.116179
#
#        tfmri_sst_all_correct.go.vs.fixation_beta_cort.destrieux_g.and.s.cingul.mid.ant.lh  \
# 0                                               0.045860
# 2                                               0.111399
# 3                                               0.182024
# 4                                              -0.001618
# 5                                              -0.078217
# ...                                                  ...
# 11870                                           0.008791
# 11871                                          -0.024308
# 11872                                           0.012343
# 11873                                           0.376726
# 11874                                          -0.045182
#
#        tfmri_sst_all_correct.go.vs.fixation_beta_cort.destrieux_g.and.s.cingul.mid.post.lh  \
# 0                                               0.081824
# 2                                               0.113433
# 3                                               0.096595
# 4                                               0.241128
# 5                                              -0.044547
# ...                                                  ...
# 11870                                           0.059300
# 11871                                          -0.143336
# 11872                                          -0.072679
# 11873                                           0.371823
# 11874                                           0.341190
#
#        tfmri_sst_all_correct.go.vs.fixation_beta_cort.destrieux_g.cingul.post.dorsal.lh  \
# 0                                               0.135374
# 2                                               0.006913
# 3                                              -0.051182
# 4                                               0.566345
# 5                                              -0.143595
# ...                                                  ...
# 11870                                          -0.020510
# 11871                                           0.045055
# 11872                                           0.013745
# 11873                                           0.118068
# 11874                                          -0.108107
#
#        ...  \
# 0      ...
# 2      ...
# 3      ...
# 4      ...
# 5      ...
# ...    ...
# 11870  ...
# 11871  ...
# 11872  ...
# 11873  ...
# 11874  ...
#
#        tfmri_sst_all_incorrect.stop.vs.correct.go_beta_subcort.aseg_cerebellum.cortex.rh  \
# 0                                               0.271985
# 2                                               0.170224
# 3                                              -0.192650
# 4                                              -0.125728
# 5                                               0.383309
# ...                                                  ...
# 11870                                           0.080321
# 11871                                           0.018032
# 11872                                           0.115288
# 11873                                          -0.508338
# 11874                                           0.465149
#
#        tfmri_sst_all_incorrect.stop.vs.correct.go_beta_subcort.aseg_thalamus.proper.rh  \
# 0                                               0.158497
# 2                                               0.044027
# 3                                              -0.113892
# 4                                               0.060963
# 5                                               0.230097
# ...                                                  ...
# 11870                                           0.055350
# 11871                                           0.034421
# 11872                                           0.388157
# 11873                                          -0.251212
# 11874                                          -0.110444
#
#        tfmri_sst_all_incorrect.stop.vs.correct.go_beta_subcort.aseg_caudate.rh  \
# 0                                               0.140130
# 2                                               0.080984
# 3                                              -0.261145
# 4                                               0.037491
# 5                                               0.195374
# ...                                                  ...
# 11870                                           0.073250
# 11871                                           0.070082
# 11872                                           0.267505
# 11873                                          -0.517297
# 11874                                          -0.029437
#
#        tfmri_sst_all_incorrect.stop.vs.correct.go_beta_subcort.aseg_putamen.rh  \
# 0                                              -0.022286
# 2                                               0.036808
# 3                                              -0.187083
# 4                                               0.092319
# 5                                               0.159455
# ...                                                  ...
# 11870                                          -0.090321
# 11871                                          -0.069077
# 11872                                           0.366650
# 11873                                          -0.380956
# 11874                                          -0.142340
#
#        tfmri_sst_all_incorrect.stop.vs.correct.go_beta_subcort.aseg_pallidum.rh  \
# 0                                              -0.025535
# 2                                               0.191424
# 3                                              -0.082544
# 4                                               0.046954
# 5                                               0.122448
# ...                                                  ...
# 11870                                           0.016314
# 11871                                           0.080907
# 11872                                           0.134182
# 11873                                          -0.347940
# 11874                                          -0.217486
#
#        tfmri_sst_all_incorrect.stop.vs.correct.go_beta_subcort.aseg_hippocampus.rh  \
# 0                                               0.029847
# 2                                              -0.070316
# 3                                              -0.126344
# 4                                              -0.340383
# 5                                               0.203364
# ...                                                  ...
# 11870                                           0.016634
# 11871                                          -0.041997
# 11872                                           0.338388
# 11873                                          -0.660557
# 11874                                          -0.046869
#
#        tfmri_sst_all_incorrect.stop.vs.correct.go_beta_subcort.aseg_amygdala.rh  \
# 0                                               0.033911
# 2                                              -0.047834
# 3                                              -0.103980
# 4                                              -0.349582
# 5                                               0.029684
# ...                                                  ...
# 11870                                          -0.017871
# 11871                                          -0.229670
# 11872                                           0.167300
# 11873                                          -0.482309
# 11874                                          -0.091805
#
#        tfmri_sst_all_incorrect.stop.vs.correct.go_beta_subcort.aseg_accumbens.area.rh  \
# 0                                              -0.006584
# 2                                              -0.071073
# 3                                              -0.127491
# 4                                              -0.177044
# 5                                               0.216518
# ...                                                  ...
# 11870                                           0.028356
# 11871                                           0.042529
# 11872                                           0.243295
# 11873                                          -0.478043
# 11874                                          -0.121216
#
#        tfmri_sst_all_incorrect.stop.vs.correct.go_beta_subcort.aseg_ventraldc.rh  \
# 0                                               0.234851
# 2                                               0.042021
# 3                                              -0.175904
# 4                                              -0.102220
# 5                                               0.230591
# ...                                                  ...
# 11870                                           0.095318
# 11871                                          -0.075879
# 11872                                           0.312342
# 11873                                          -0.336481
# 11874                                           0.036157
#
#        sex
# 0        0
# 2        1
# 3        1
# 4        1
# 5        1
# ...    ...
# 11870    1
# 11871    0
# 11872    0
# 11873    0
# 11874    0
#
# [8520 rows x 509 columns]

# %% [markdown]
# ## Define an ML Pipeline

# %%
# Let's define a Pipeline, first by creating a series of based objects

# Standard Scaling
scaler = bp.Scaler('standard', scope='float')

# Ridge Regression model
ridge = bp.Model('ridge', params=1)

# Parameter search strategy,
# using different evolution and a custom nested
# CV strategy.
search = bp.ParamSearch(search_type='DE',
                        n_iter=60,
                        cv=bp.CV(splits=.5,
                                 n_repeats=5))

pipe = bp.Pipeline([scaler, ridge], param_search=search)
pipe
# Out:
# Pipeline(param_search=ParamSearch(cv=CV(cv_strategy=CVStrategy(), n_repeats=5,
#                                         splits=0.5),
#                                   n_iter=60, search_type='DE'),
#          steps=[Scaler(obj='standard'), Model(obj='ridge', params=1)])

# %% [markdown]
# ## Evaluating an ML Pipeline

# %%
# We can store some commonly used parameters in this
# ProblemSpec object. Though note, problem_type and scorer can both be automatically
# detected and set.
spec = bp.ProblemSpec(problem_type='regression',
                      scorer=['r2', 'explained_variance', 'neg_mean_squared_error'],
                      random_state=51,
                      n_jobs=8)

# %%
results = bp.evaluate(pipeline=pipe,
                      dataset=data,
                      problem_spec=spec,
                      subjects='train', # This line is important! It says we only want to evaluate on the train set
                      cv=3)
results
# Out:
# Folds:   0%|          | 0/3 [00:00<?, ?it/s]
# BPtEvaluator
# ------------
# mean_scores = {'r2': 0.07958835201902088, 'explained_variance': 0.07967997124605375, 'neg_mean_squared_error': -6010.648630526718}
# std_scores = {'r2': 0.011299061390542244, 'explained_variance': 0.01136276831924015, 'neg_mean_squared_error': 69.94297102088669}
#
# Saved Attributes: ['estimators', 'preds', 'timing', 'train_indices', 'val_indices', 'feat_names', 'ps', 'mean_scores', 'std_scores', 'weighted_mean_scores', 'scores', 'fis_', 'coef_']
#
# Avaliable Methods: ['get_preds_dfs', 'get_fis', 'get_coef_', 'permutation_importance']
#
# Evaluated with:
# ProblemSpec(n_jobs=8, problem_type='regression', random_state=51,
#             scorer={'explained_variance': make_scorer(explained_variance_score),
#                     'neg_mean_squared_error': make_scorer(mean_squared_error, greater_is_better=False),
#                     'r2': make_scorer(r2_score)},
#             subjects='train', target='tfmri_sst_all_beh_total_mean.rt')

# %%
# Helper to get mean feature importances, in this case beta weights
results.get_fis(mean=True)
# Out:
# tfmri_sst_all_correct.go.vs.fixation_beta_cort.destrieux_g.and.s.cingul.ant.lh         0.076272
# tfmri_sst_all_correct.go.vs.fixation_beta_cort.destrieux_g.and.s.cingul.ant.rh        -0.028153
# tfmri_sst_all_correct.go.vs.fixation_beta_cort.destrieux_g.and.s.cingul.mid.ant.lh     0.595893
# tfmri_sst_all_correct.go.vs.fixation_beta_cort.destrieux_g.and.s.cingul.mid.ant.rh    -0.645362
# tfmri_sst_all_correct.go.vs.fixation_beta_cort.destrieux_g.and.s.cingul.mid.post.lh   -0.886834
#                                                                                          ...
# tfmri_sst_all_incorrect.stop.vs.correct.go_beta_subcort.aseg_putamen.rh                3.186791
# tfmri_sst_all_incorrect.stop.vs.correct.go_beta_subcort.aseg_thalamus.proper.lh       -0.889136
# tfmri_sst_all_incorrect.stop.vs.correct.go_beta_subcort.aseg_thalamus.proper.rh       -1.596109
# tfmri_sst_all_incorrect.stop.vs.correct.go_beta_subcort.aseg_ventraldc.lh             -1.066655
# tfmri_sst_all_incorrect.stop.vs.correct.go_beta_subcort.aseg_ventraldc.rh             -1.562604
# Length: 507, dtype: float32

# %% [markdown]
# Since a train-test split is being employed, there would at this stage likely be some sort of exploration of different pipelines. Or for example exploration with a limited feature set, i.e., what if we only want to try one of the contrasts? We can just specify a scope.

# %%
results = bp.evaluate(pipeline=pipe,
                      dataset=data,
                      problem_spec=spec,
                      scope='tfmri_sst_all_incorrect.stop.vs.correct.go_beta_',
                      subjects='train',
                      cv=3)
results
# Out:
# Folds:   0%|          | 0/3 [00:00<?, ?it/s]
# BPtEvaluator
# ------------
# mean_scores = {'r2': 0.05327251543145987, 'explained_variance': 0.05329305687623639, 'neg_mean_squared_error': -6182.876918714411}
# std_scores = {'r2': 0.0021388040737987894, 'explained_variance': 0.0021417335422099413, 'neg_mean_squared_error': 64.79142619569838}
#
# Saved Attributes: ['estimators', 'preds', 'timing', 'train_indices', 'val_indices', 'feat_names', 'ps', 'mean_scores', 'std_scores', 'weighted_mean_scores', 'scores', 'fis_', 'coef_']
#
# Avaliable Methods: ['get_preds_dfs', 'get_fis', 'get_coef_', 'permutation_importance']
#
# Evaluated with:
# ProblemSpec(n_jobs=8, problem_type='regression', random_state=51,
#             scope='tfmri_sst_all_incorrect.stop.vs.correct.go_beta_',
#             scorer={'explained_variance': make_scorer(explained_variance_score),
#                     'neg_mean_squared_error': make_scorer(mean_squared_error, greater_is_better=False),
#                     'r2': make_scorer(r2_score)},
#             subjects='train', target='tfmri_sst_all_beh_total_mean.rt')

# %% [markdown]
# Or along the same lines, we could also specify a sub-set of subects to evaluate by. We can use two custom input objects for this.

# %%
sex_m = bp.ValueSubset('sex', 'M', decode_values=True)
sex_f = bp.ValueSubset('sex', 'F', decode_values=True)

sex_m_train = bp.Intersection(['train', sex_m])
sex_f_train = bp.Intersection(['train', sex_f])

# Look at what this refers to explicitly
len(data.get_subjects(sex_m_train)), len(data.get_subjects(sex_f_train))
# Out:
# (3478, 3338)

# %%
results = bp.evaluate(pipeline=pipe,
                      dataset=data,
                      problem_spec=spec,
                      scope='tfmri_sst_all_incorrect.stop.vs.correct.go_beta_',
                      subjects=sex_m_train,
                      cv=3)
results
# Out:
# Folds:   0%|          | 0/3 [00:00<?, ?it/s]
# BPtEvaluator
# ------------
# mean_scores = {'r2': 0.034197426384785214, 'explained_variance': 0.03591829920893741, 'neg_mean_squared_error': -6377.342769373649}
# std_scores = {'r2': 0.009918181711194539, 'explained_variance': 0.008886290552314522, 'neg_mean_squared_error': 472.49320657711036}
#
# Saved Attributes: ['estimators', 'preds', 'timing', 'train_indices', 'val_indices', 'feat_names', 'ps', 'mean_scores', 'std_scores', 'weighted_mean_scores', 'scores', 'fis_', 'coef_']
#
# Avaliable Methods: ['get_preds_dfs', 'get_fis', 'get_coef_', 'permutation_importance']
#
# Evaluated with:
# ProblemSpec(n_jobs=8, problem_type='regression', random_state=51,
#             scope='tfmri_sst_all_incorrect.stop.vs.correct.go_beta_',
#             scorer={'explained_variance': make_scorer(explained_variance_score),
#                     'neg_mean_squared_error': make_scorer(mean_squared_error, greater_is_better=False),
#                     'r2': make_scorer(r2_score)},
#             subjects=Intersection(['train', ValueSubset(name=sex, values=M, decode_values=True)]),
#             target='tfmri_sst_all_beh_total_mean.rt')

# %% [markdown]
# ## Comparing different pipelines
#
# What if we wanted to explicitly compare results by sex? We have another special objects for that called Compare. Compare will run a seperate evaluate for each Option, where an Option represents a choice.

# %%
compare_subjects = bp.Compare([bp.Option(sex_m_train, name='M'),
                               bp.Option(sex_f_train, name='F')])

results = bp.evaluate(pipeline=pipe,
                      dataset=data,
                      problem_spec=spec,
                      scope='tfmri_sst_all_incorrect.stop.vs.correct.go_beta_',
                      subjects=compare_subjects,
                      cv=3)

# The returned CompareDict has a special summary method
results.summary()
# Out:
# Compare:   0%|          | 0/2 [00:00<?, ?it/s]
# Folds:   0%|          | 0/3 [00:00<?, ?it/s]
#           mean_scores_r2  mean_scores_explained_variance  \
# subjects
# M               0.034131                        0.035845
# F               0.052582                        0.052905
#
#           mean_scores_neg_mean_squared_error  std_scores_r2  \
# subjects
# M                               -6378.247334       0.010393
# F                               -6110.135241       0.008767
#
#           std_scores_explained_variance  std_scores_neg_mean_squared_error  \
# subjects
# M                              0.009315                         479.321623
# F                              0.008552                         494.207478
#
#           mean_timing_fit  mean_timing_score
# subjects
# M                8.171629           0.021138
# F                8.100935           0.021509

# %%
# The seperate run results can be indexed like
results['subjects=M']

# or
results['M']
# Out:
# BPtEvaluator
# ------------
# mean_scores = {'r2': 0.03413090441230645, 'explained_variance': 0.035844790893218494, 'neg_mean_squared_error': -6378.247334379688}
# std_scores = {'r2': 0.010393233471606603, 'explained_variance': 0.009314796163100483, 'neg_mean_squared_error': 479.32162264542654}
#
# Saved Attributes: ['estimators', 'preds', 'timing', 'train_indices', 'val_indices', 'feat_names', 'ps', 'mean_scores', 'std_scores', 'weighted_mean_scores', 'scores', 'fis_', 'coef_']
#
# Avaliable Methods: ['get_preds_dfs', 'get_fis', 'get_coef_', 'permutation_importance']
#
# Evaluated with:
# ProblemSpec(n_jobs=8, problem_type='regression', random_state=51,
#             scope='tfmri_sst_all_incorrect.stop.vs.correct.go_beta_',
#             scorer={'explained_variance': make_scorer(explained_variance_score),
#                     'neg_mean_squared_error': make_scorer(mean_squared_error, greater_is_better=False),
#                     'r2': make_scorer(r2_score)},
#             subjects=Intersection(['train', ValueSubset(name=sex, values=M, decode_values=True)]),
#             target='tfmri_sst_all_beh_total_mean.rt')

# %% [markdown]
# ## Using the Test Set
#
# While in practice you might want to explore more options with the train set first, let's just move on to showing how we could test a final pipeline on the testing set, while training on the full train set.

# %%
results = bp.evaluate(pipeline=pipe,
                      dataset=data,
                      problem_spec=spec,
                      scope='all', # Use all three contrasts
                      subjects='all', # Use all subjects, not just train
                      cv='test' # Special argument to train on full train and test on test
                     )
results
# Out:
# Folds:   0%|          | 0/1 [00:00<?, ?it/s]
# BPtEvaluator
# ------------
# mean_scores = {'r2': 0.0767273508156815, 'explained_variance': 0.07683723130501696, 'neg_mean_squared_error': -5918.334587246385}
# std_scores = {'r2': 0.0, 'explained_variance': 0.0, 'neg_mean_squared_error': 0.0}
#
# Saved Attributes: ['estimators', 'preds', 'timing', 'train_indices', 'val_indices', 'feat_names', 'ps', 'mean_scores', 'std_scores', 'weighted_mean_scores', 'scores', 'fis_', 'coef_']
#
# Avaliable Methods: ['get_preds_dfs', 'get_fis', 'get_coef_', 'permutation_importance']
#
# Evaluated with:
# ProblemSpec(n_jobs=8, problem_type='regression', random_state=51,
#             scorer={'explained_variance': make_scorer(explained_variance_score),
#                     'neg_mean_squared_error': make_scorer(mean_squared_error, greater_is_better=False),
#                     'r2': make_scorer(r2_score)},
#             target='tfmri_sst_all_beh_total_mean.rt')

# %%
fis = results.get_fis(mean=True)
fis
# Out:
# tfmri_sst_all_correct.go.vs.fixation_beta_cort.destrieux_g.and.s.cingul.ant.lh         0.111337
# tfmri_sst_all_correct.go.vs.fixation_beta_cort.destrieux_g.and.s.cingul.ant.rh        -0.065363
# tfmri_sst_all_correct.go.vs.fixation_beta_cort.destrieux_g.and.s.cingul.mid.ant.lh     0.730217
# tfmri_sst_all_correct.go.vs.fixation_beta_cort.destrieux_g.and.s.cingul.mid.ant.rh    -0.797279
# tfmri_sst_all_correct.go.vs.fixation_beta_cort.destrieux_g.and.s.cingul.mid.post.lh   -1.403382
#                                                                                          ...
# tfmri_sst_all_incorrect.stop.vs.correct.go_beta_subcort.aseg_putamen.rh                4.141865
# tfmri_sst_all_incorrect.stop.vs.correct.go_beta_subcort.aseg_thalamus.proper.lh       -1.177651
# tfmri_sst_all_incorrect.stop.vs.correct.go_beta_subcort.aseg_thalamus.proper.rh       -2.324470
# tfmri_sst_all_incorrect.stop.vs.correct.go_beta_subcort.aseg_ventraldc.lh             -1.157101
# tfmri_sst_all_incorrect.stop.vs.correct.go_beta_subcort.aseg_ventraldc.rh             -1.738446
# Length: 507, dtype: float32

# %% [markdown]
# ## Plotting results
#
# To plot feature importance results we are going to use a different library avaliable at https://github.com/sahahn/Neuro_Plotting, in addition to the library nilearn.

# %%
import matplotlib.pyplot as plt
from nilearn.plotting import plot_glass_brain, plot_stat_map

# We will use some extra loading functions
from Neuro_Plotting.Ref import SurfRef, VolRef, load_mapping, save_mapping
from Neuro_Plotting.Plot import Plot_Surf, Plot_Surf_Collage, Plot_SurfVol_Collage

# %%
# The directory where you install Neuro_Plotting
data_dr = '/home/sage/Neuro_Plotting/data/'

# %%
# Need as DataFrame not Series
fis_df = pd.DataFrame(fis).reset_index()
fis_df
# Out:
#                                                  index         0
# 0    tfmri_sst_all_correct.go.vs.fixation_beta_cort...  0.111337
# 1    tfmri_sst_all_correct.go.vs.fixation_beta_cort... -0.065363
# 2    tfmri_sst_all_correct.go.vs.fixation_beta_cort...  0.730217
# 3    tfmri_sst_all_correct.go.vs.fixation_beta_cort... -0.797279
# 4    tfmri_sst_all_correct.go.vs.fixation_beta_cort... -1.403382
# ..                                                 ...       ...
# 502  tfmri_sst_all_incorrect.stop.vs.correct.go_bet...  4.141865
# 503  tfmri_sst_all_incorrect.stop.vs.correct.go_bet... -1.177651
# 504  tfmri_sst_all_incorrect.stop.vs.correct.go_bet... -2.324470
# 505  tfmri_sst_all_incorrect.stop.vs.correct.go_bet... -1.157101
# 506  tfmri_sst_all_incorrect.stop.vs.correct.go_bet... -1.738446
#
# [507 rows x 2 columns]

# %%
surf_ref = SurfRef(data_dr, space='fsaverage5', parc='destr')

# Get beta weights seperate by contrast and hemisphere
betas = []
for c_key in contrasts:
    
    b = surf_ref.get_hemis_plot_vals(fis_df,
                                     lh_key='.lh',
                                     rh_key='.rh',
                                     i_keys=['.destrieux', c_key])
    betas.append(b)

# %%
for i in range(len(betas)):
    figure, axes, smf = Plot_Surf_Collage(data = betas[i],
                                          ref = surf_ref,
                                          surf_mesh = 'pial',
                                          bg_map = 'sulc',
                                          view = 'standard',
                                          cmap = 'seismic',
                                          title = contrasts[i],
                                          title_sz = 22,
                                          threshold = 1,
                                          dist= 6.25,
                                          wspace = 0,
                                          hspace = 0,
                                          figsize = (15, 10),
                                          avg_method = 'median',
                                          bg_on_data = True,
                                          alpha = 1,
                                          colorbar = True)
    
    # Optionally save data
    #plt.savefig(contrast_keys[i] + '.png', dpi=100, bbox_inches='tight')

# %%
vol_ref = VolRef(data_dr, space='mni', parc='aseg_2mm')

vols = []
for c_key in contrasts:
    vols.append(vol_ref.get_plot_vals(fis_df, i_keys=['_subcort.aseg', c_key], d_keys=[]))

vols
# Out:
# [<nibabel.nifti1.Nifti1Image at 0x7f485812ab50>,
#  <nibabel.nifti1.Nifti1Image at 0x7f485813a820>,
#  <nibabel.nifti1.Nifti1Image at 0x7f4899a237c0>]

# %%
for i in range(len(contrasts)):
    plot_glass_brain(vols[i], colorbar=True, title=contrasts[i])
    plot_stat_map(vols[i], title=contrasts[i])
